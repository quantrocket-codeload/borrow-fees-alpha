# %% [markdown]
# <a href="https://www.quantrocket.com"><img alt="QuantRocket logo" src="https://www.quantrocket.com/assets/img/notebook-header-logo.png"></a>

# %% [markdown]
# ***
# [Borrow Fees Alpha](Introduction.ipynb) › Part 7: Zipline Parameter Scan
# ***

# %% [markdown]
# # Zipline Parameter Scan
#
# Parameter scans provide a convenient way to determine the effect of excluding stocks with high borrow fees. First, run the scan:

# %%
from quantrocket.zipline import scan_parameters
scan_parameters(
    "avoid-high-borrow", 
    start_date="2018-04-16", 
    end_date="2024-04-30", 
    capital_base=2e5,
    param1="MAX_BORROW_FEE",
    vals1=[None, 0.3],
    filepath_or_buffer="avoid_high_borrow_MAX_BORROW_FEE_results.csv", 
    progress="M")

# %% [markdown]
# Then view the tear sheet:

# %%
from moonchart import ParamscanTearsheet
ParamscanTearsheet.from_csv("avoid_high_borrow_MAX_BORROW_FEE_results.csv")

# %% [markdown]
# ***
#
# [Back to Introduction](Introduction.ipynb)
